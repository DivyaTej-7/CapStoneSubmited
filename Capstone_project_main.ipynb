# %%
import os
import json
import requests
from bs4 import BeautifulSoup

def scrape_manga(base_url="https://mangapark.io/latest/action", output_file="manga_data.json", max_pages=55):
    page_number = 1
    existing_data = {}

    if os.path.exists(output_file):
        with open(output_file, "r") as file:
            existing_data = json.load(file)

    while page_number <= max_pages:
        url = f"{base_url}/{page_number}"
        print(f"Scraping page: {url}")

        response = requests.get(url)
        if response.status_code != 200:
            print(f"Reached an invalid page or failed request at page {page_number}. Stopping.")
            break

        soup = BeautifulSoup(response.content, "html.parser")

        manga_list = soup.select("div.flex.border-b.border-b-base-200.pb-3")
        if not manga_list:
            print("No more manga found. Ending scraping.")
            break

        for manga in manga_list:
            title = manga.select_one("h3.font-bold span").text.strip()
            image_url = manga.select_one("div.group.relative img")["src"]
            details_url = "https://mangapark.io" + manga.select_one("h3.font-bold a")["href"]

            rating_element = manga.select_one("span.flex.items-center.text-yellow-500 span.font-bold")
            rating = rating_element.text.strip() if rating_element else "NA"

            genres = [genre.text.strip() for genre in manga.select("div.flex.flex-wrap.text-xs span span")]

            if title in existing_data:
                print(f"{title} already exists. Skipping.")
            else:
                existing_data[title] = {
                    "image_url": image_url,
                    "details_url": details_url,
                    "genres": genres,
                    "rating": rating
                }
                print(f"Added {title}")

        print(f"Finished scraping page {page_number}")
        page_number += 1

    with open(output_file, "w") as file:
        json.dump(existing_data, file, indent=4)
    print(f"Data saved to {output_file}")

scrape_manga()
# Out:
# Scraping page: https://mangapark.io/latest/action/1
# Gomi Ika da to Tsuihousareta Shounin, Jitsu wa Zensei Kensha desu already exists. Skipping.
# Added Eternal Life (Novel)
# Added Beastbox: The Mecha Era
# Daxia Swordsman already exists. Skipping.
# Apocalyptic Super Farm already exists. Skipping.
# Added Silvyre
# Virus King already exists. Skipping.
# The Reincarnated Assassin Is A Genius Swordsman already exists. Skipping.
# Catastrophic Priest already exists. Skipping.
# Trait Hoarder already exists. Skipping.
# Heavenly Inquisition Sword already exists. Skipping.
# Drug Devourer already exists. Skipping.
# Freezing The World: I Built A Doomsday Safehouse already exists. Skipping.
# I Get Stronger Just By Lying Down While My Apprentice Cultivates already exists. Skipping.
# The Best Female Fairy already exists. Skipping.
# Global Martial Arts already exists. Skipping.
# Catastrophic Priest already exists. Skipping.
# I’ll Retire After Saving the World already exists. Skipping.
# Finished scraping page 1
# Scraping page: https://mangapark.io/latest/action/2
# Ghost Fixers already exists. Skipping.
# Hardcore Leveling Warrior already exists. Skipping.
# Against the Gods already exists. Skipping.
# I'm the Max-Level Newbie already exists. Skipping.
# Spare Me, Great Lord! already exists. Skipping.
# The Immortal Emperor Luo Wuji Has Returned already exists. Skipping.
# The Executioner already exists. Skipping.
# Mowang Zuobi Xitong already exists. Skipping.
# Omniscient Reader already exists. Skipping.
# Apocalypse Bug Master already exists. Skipping.
# The Hero Went Crazy Even Though I'm the One Who Died already exists. Skipping.
# Home Plate Villain already exists. Skipping.
# Male Lead, I’ll Respect Your Taste already exists. Skipping.
# 0.0000001% Demon King-Nim already exists. Skipping.
# One-Punch Man already exists. Skipping.
# The Great Master already exists. Skipping.
# The Hero Became The Duke's Eldest Son already exists. Skipping.
# Return Of The Sword God-Rank Civil Servant already exists. Skipping.
# Archmage Transcending Through Regression already exists. Skipping.
# I'm The Great Immortal already exists. Skipping.
# Hero Has Returned already exists. Skipping.
# Hero Has Returned (Fungback) already exists. Skipping.
# I'm the Great Immortal already exists. Skipping.
# The Strong Man From The Mental Hospital already exists. Skipping.
# Surviving With an SSS-Rank Inventory already exists. Skipping.
# Son-in-Law Above Them All already exists. Skipping.
# The More I Die, The More Invincible I Become already exists. Skipping.
# Battle Royale Enforcers already exists. Skipping.
# I Randomly Have A New Career Every Week already exists. Skipping.
# I Contracted Myself already exists. Skipping.
# A Sense Of Amusement already exists. Skipping.
# Berserk of Gluttony already exists. Skipping.
# Yu-Gi-Oh! OGC Structures already exists. Skipping.
# Absolute superman already exists. Skipping.
# Poisonous Doctor: First Wife’s Daughter already exists. Skipping.
# Invincibility Begins With A Broken Hand already exists. Skipping.
# Finished scraping page 2
# Scraping page: https://mangapark.io/latest/action/3
# Watchmaker’S Revenge already exists. Skipping.
# Ni Tian Xie Shen (Novel) already exists. Skipping.
# That Boy Is A Monster already exists. Skipping.
# Killer Or Saver already exists. Skipping.
# Otoko Ippiki Gaki Daishou already exists. Skipping.
# Male Lead Likes My Support! already exists. Skipping.
# High School Boy already exists. Skipping.
# absolute batman already exists. Skipping.
# It Starts With a Kingpin Account already exists. Skipping.
# I'm Stuck on the Same Day for a Thousand Years already exists. Skipping.
# Apocalyptic Super Farm already exists. Skipping.
# My Status Window Is On Strike already exists. Skipping.
# The Time of Rebirth already exists. Skipping.
# Limitless Ascension: Strength Amid Adversity already exists. Skipping.
# Manager Kim already exists. Skipping.
# Reincarnation Of The Sword Master already exists. Skipping.
# The Hero Academy’s Student Of Revenge already exists. Skipping.
# Infection already exists. Skipping.
# Long Live Arcadia already exists. Skipping.
# The Wallflower Who Was Proposed To By The Tyrant already exists. Skipping.
# noHEROES! already exists. Skipping.
# 9 Wonder Worlds already exists. Skipping.
# Executioner already exists. Skipping.
# School of the Malice already exists. Skipping.
# Eternal Club already exists. Skipping.
# I’Ll Retire After Saving The World already exists. Skipping.
# Jobless, Yet Invincible already exists. Skipping.
# Heavenly Demon Wants to Be A Chef already exists. Skipping.
# Wind Breaker (Nll Satoru) already exists. Skipping.
# My Girlfriend Is a Zombie already exists. Skipping.
# Infinite Deduction already exists. Skipping.
# The Constellation That Returned From Hell already exists. Skipping.
# Summoners War: Cross already exists. Skipping.
# The Earth Savior Selection already exists. Skipping.
# Mai Xiang Ke Li Ma Sha already exists. Skipping.
# My Insanely Competent Underlings already exists. Skipping.
# Finished scraping page 3
# Scraping page: https://mangapark.io/latest/action/4
# Kalli the Champion already exists. Skipping.
# Revenge of the bloom flower already exists. Skipping.
# Soul Catcher(S) already exists. Skipping.
# King Of Violence already exists. Skipping.
# The Secret Of Darkness Garden already exists. Skipping.
# It Turns Out That I Have Been Invincible For A Long Time already exists. Skipping.
# Ride-On King already exists. Skipping.
# Daedalus Of The Crows already exists. Skipping.
# Tyranny already exists. Skipping.
# Chi to Hai no Joou already exists. Skipping.
# My Dragon System already exists. Skipping.
# Since The Red Moon Appeared already exists. Skipping.
# The Reincarnated Marriage of a Hero and a Sage: After Becoming Engaged to a Former Rival, We Became the Strongest Couple already exists. Skipping.
# I'm Really Not The Villain already exists. Skipping.
# Immortal Maestro already exists. Skipping.
# Summoner Wars: Trackers already exists. Skipping.
# Solo Eating already exists. Skipping.
# The Distinguished Cute Master already exists. Skipping.
# Swallow Knights Tales already exists. Skipping.
# Cloud Walker already exists. Skipping.
# Tale Of A Scribe Who Retires To The Countryside already exists. Skipping.
# Deadly Class already exists. Skipping.
# Transmetropolitan already exists. Skipping.
# The Bully In-Charge already exists. Skipping.
# Level up Alone already exists. Skipping.
# The Ultimate of All Ages already exists. Skipping.
# Forced to Become the Villainous Son-in-law already exists. Skipping.
# Carnivorous Hunter already exists. Skipping.
# Warrior High School - Dungeon Raid Department already exists. Skipping.
# Genius Doctor Lee Moo-jin already exists. Skipping.
# Record Of Ragnarok: The Apocalypse Of The Gods already exists. Skipping.
# Hero the Maximum already exists. Skipping.
# Hero Killer already exists. Skipping.
# Good-For-Nothing Blues already exists. Skipping.
# Grave Of Swords already exists. Skipping.
# My Best Friend Is An Eldritch Horror already exists. Skipping.
# Finished scraping page 4
# Scraping page: https://mangapark.io/latest/action/5
# Taberu dake de Level Up!: Damegami to Issho ni Isekai Musou already exists. Skipping.
# Dong Gun already exists. Skipping.
# The Last Golden Child already exists. Skipping.
# Hazure Hantei kara Hajimatta Cheat Majutsushi Seikatsu already exists. Skipping.
# Using My Cooking Skills In A Murim World already exists. Skipping.
# If You Wish For A Married Couple’S Duties already exists. Skipping.
# I’M A Solo Guide already exists. Skipping.
# Tu Di Dou Shi Nv Mo Tou already exists. Skipping.
# My Insanely Strong Henchmen already exists. Skipping.
# Shuumatsu no Walküre already exists. Skipping.
# ??? Rank No Ura Soubi Musou already exists. Skipping.
# The Heavenly Demon Lord Who Doesn't Want to Level Up already exists. Skipping.
# Logging 10,000 years into the future already exists. Skipping.
# Apocalypse 100% Drop Rate already exists. Skipping.
# Madara Ramble already exists. Skipping.
# The Regressed Demon Lord Is Kind already exists. Skipping.
# What, You Dare Pretend in Front of Me, the Strongest in the Immortal World? already exists. Skipping.
# Gimmick! already exists. Skipping.
# God of Martial Arts already exists. Skipping.
# Gimmick! (YABUGUCHI Kuroko) already exists. Skipping.
# Skeleton Soldier Couldn't Protect the Dungeon already exists. Skipping.
# Sangyang:the Wanderer already exists. Skipping.
# Gaming Stream of the Genius already exists. Skipping.
# Isekai Kaeri no Yuusha wa, Dungeon ga Shutsugen shita Genjitsu Sekai de, Influencer natte Kane wo Kasegimasu! already exists. Skipping.
# Archmage Transcending Through Regression already exists. Skipping.
# Trigun Maximum already exists. Skipping.
# Isekai De Mizu No Dai Seirei Yattemasu already exists. Skipping.
# Absolute Submission already exists. Skipping.
# I'm Really Not the Demon God's Lackey already exists. Skipping.
# Martial Arts Alone already exists. Skipping.
# The Strongest Magical Swordsman Ever Reborn as an F-Rank Adventurer already exists. Skipping.
# There is no true peace in this world -Shin Kamen Rider SHOCKER SIDE- already exists. Skipping.
# Demonic Spirit King already exists. Skipping.
# Epsilon already exists. Skipping.
# Hazure Zokusei "Hikari Mahou" Ga Kakusei Shite Laser Ga Demashita already exists. Skipping.
# Eleceed (Official) already exists. Skipping.
# Finished scraping page 5
# Scraping page: https://mangapark.io/latest/action/6
# Terminally-Ill Genius Dark Knight already exists. Skipping.
# Absolute Obedience already exists. Skipping.
# Tekno already exists. Skipping.
# The Return Of The Legendary Archmage already exists. Skipping.
# Traveling Through Time And Space To Become An Unlucky Npc: I Have A Wife To Protect Me already exists. Skipping.
# Top 1 Fighting Tutoring already exists. Skipping.
# High Class already exists. Skipping.
# The World After the Fall already exists. Skipping.
# True Education already exists. Skipping.
# Chronicles Of A Returner already exists. Skipping.
# Infinite Level Up In Murim already exists. Skipping.
# Surviving The Game As A Barbarian already exists. Skipping.
# The Evil Ring already exists. Skipping.
# Tsuki ga Michibiku Isekai Douchuu already exists. Skipping.
# Starting as the Black Dragon Boss, I Am Invincible already exists. Skipping.
# Nimotsu Mochi no Nousuji Musou already exists. Skipping.
# I Am the Shadow Reverend already exists. Skipping.
# My Disciples Are All Big Villains already exists. Skipping.
# “Jako Ni Ha Tanya Ga Oniaida Www” to Iwareta Tanya Level 9999 No Ore, Tsuiho Saretanode Boken Sha Ni Tenshoku Suru Saikyo Buki De Muso Shinagara Guild De Tanoshiku Kurashimasu already exists. Skipping.
# Maougun Saikyou no Majutsushi wa Ningen datta already exists. Skipping.
# 99 Reinforced Wood Stick already exists. Skipping.
# Nine Peaks already exists. Skipping.
# Reality Quest already exists. Skipping.
# Martial Peak already exists. Skipping.
# Maou Gun Saikyou no Majutsushi wa Ningen datta already exists. Skipping.
# Chiruran: Shinsengumi Requiem already exists. Skipping.
# Master: This Villainous Disciple Is Not The Holy Child already exists. Skipping.
# Warrior Grandpa And Grandmaster Daughter already exists. Skipping.
# The Strongest Tamer Returned From Another World With His Childhood Friend As His Familiar already exists. Skipping.
# The Regressor Protects Only Me already exists. Skipping.
# Youchien wars already exists. Skipping.
# Kengan Omega already exists. Skipping.
# The Start of a Stunning and Feisty Master: A System with Ten Pounds of Rebellion already exists. Skipping.
# Kaijin Mira No Dai 2 Keitai Ga Kawaisugiru already exists. Skipping.
# Dungeon Defense already exists. Skipping.
# Warrior Grandpa And Supreme Granddaughter already exists. Skipping.
# Finished scraping page 6
# Scraping page: https://mangapark.io/latest/action/7
# Rebirth Of The Urban Immortal Cultivator already exists. Skipping.
# Kengan Omega already exists. Skipping.
# Monster Pet Evolution already exists. Skipping.
# Necromancer Academy And The Genius Summoner already exists. Skipping.
# Wo De Meng Bao Shi Liaoji already exists. Skipping.
# Saiaku No Avalon already exists. Skipping.
# Raising a Newbie to Grind Them already exists. Skipping.
# A Not So Fairy Tale already exists. Skipping.
# Kurotonbi no Seija already exists. Skipping.
# Mobile War History Gundam Burai already exists. Skipping.
# Housekeeper (Chae Yong-Taek) already exists. Skipping.
# Amelia The Level Zero Hero already exists. Skipping.
# Weapon Maker already exists. Skipping.
# King's Game already exists. Skipping.
# Housekeeper already exists. Skipping.
# Wandering Warrior of Wudang already exists. Skipping.
# Kaiju No. 8 already exists. Skipping.
# Return of the Broken Constellation already exists. Skipping.
# Son's Retribution already exists. Skipping.
# Finished scraping page 8
# Scraping page: https://mangapark.io/latest/action/9
# Childhood Friend of the Zenith already exists. Skipping.
# Surviving as a Genius on Borrowed Time already exists. Skipping.
# Ore wa Subete o "Parry" Suru: Gyaku Kanchigai no Sekai Saikyou wa Boukensha ni Naritai already exists. Skipping.
# Bad Ending Maker already exists. Skipping.
# Surviving As A Genius On Borrowed Time already exists. Skipping.
# Divine Delivery already exists. Skipping.
# Omniscient Reader's Viewpoint already exists. Skipping.
# Dragon Master already exists. Skipping.
# Eternal First God already exists. Skipping.
# Shaman Girl already exists. Skipping.
# The Ninth-Rank Sword Master: Conquering the Sword Forms already exists. Skipping.
# The Ghostly Doctor already exists. Skipping.
# Fate Rewinder already exists. Skipping.
# Yi Hou Li Tian: Shenyi Di Nv Hen Juese already exists. Skipping.
# 1st year Max Level Manager already exists. Skipping.
# The Heavenly Demon Wants a Quiet Life already exists. Skipping.
# Saving 80,000 Gold Coins in the Different World for My Old Age already exists. Skipping.
# Tank Chair already exists. Skipping.
# Jahy-sama Won't Be Discouraged! already exists. Skipping.
# Respawn: Usurping The Imperial Throne With My Extra Lives already exists. Skipping.
# Gachiakuta already exists. Skipping.
# Dear Shimazaki in the Peaceful Land already exists. Skipping.
# Becoming the Swordmaster Rank Young Lord of the Sichuan Tang Family already exists. Skipping.
# Only I Know the World Is Ending And Getting Killed by Rampaging Beasts Only Makes Me Stronger already exists. Skipping.
# Super God Gene (Novel) already exists. Skipping.
# Invincible After Shocking My Empress Wife already exists. Skipping.
# Invincible After Shocking My Empress Wife already exists. Skipping.
# Overlord of Insects already exists. Skipping.
# I Thought It Was A Common Isekai Story already exists. Skipping.
# Jahy-sama ha Kujikenai! already exists. Skipping.
# Versus (AZUMA Kyoutarou) already exists. Skipping.
# Designs already exists. Skipping.
# Henkyou no Roukishi Bard Loen already exists. Skipping.
# The Exiled Heavy Knight Knows How to Game the System already exists. Skipping.
# Rougo ni Sonaete Isekai de 8-manmai no Kinka o Tamemasu already exists. Skipping.
# Even Given the Worthless "Appraiser" Class, I'm Actually the Strongest already exists. Skipping.
# Finished scraping page 9
# Scraping page: https://mangapark.io/latest/action/10
# Han Dae Sung Returned From Hell already exists. Skipping.
# THE PART TIME NATION OF THE GODS already exists. Skipping.
# The Archmage's Restaurant already exists. Skipping.
# Supreme Zerg Lord already exists. Skipping.
# Million Times Attack Speed already exists. Skipping.
# All football Talents Are Mine already exists. Skipping.
# The Lord's Coins Aren't Decreasing?! already exists. Skipping.
# Soul Land V already exists. Skipping.
# Douluo Dalu 5 Chongsheng Tangsan already exists. Skipping.
# Isekai Meikyuu no Saishinbu o Mezasou already exists. Skipping.
# Henkyou Gurashi no Maou, Tensei shite Saikyou no Majutsushi ni naru ~Aisarenagara Nariagaru Moto Maou wa, Ningen o Shiritai~ already exists. Skipping.
# Shangri-La Frontier already exists. Skipping.
# Valhalla Saga already exists. Skipping.
# The Hero Who Seeks Revenge Shall Exterminate with Darkness already exists. Skipping.
# Four Knights of the Apocalypse already exists. Skipping.
# Kai-Hen Wizards already exists. Skipping.
# Road to Heaven already exists. Skipping.
# Saijaku Muhai no Shinsou Kiryuu already exists. Skipping.
# Granny already exists. Skipping.
# GALAXIAS (Pre-Serialization) already exists. Skipping.
# Avatar: distorted reality already exists. Skipping.
# Skeleton Soldier already exists. Skipping.
# Xiuluo Wushen (Novel) already exists. Skipping.
# I Returned As An FFF-Class Witch Doctor already exists. Skipping.
# Sekai no Owari no Sekairoku already exists. Skipping.
# Dragon Prince Yuan already exists. Skipping.
# Tales of Demons and Gods already exists. Skipping.
# The Debt Collector Who’S An Older Girl Takes Care Of Me Little By Little already exists. Skipping.
# VERSUS already exists. Skipping.
# Fukushuu o Koinegau Saikyou Yuusha wa, Yami no Chikara de Senmetsu Musou Suru already exists. Skipping.
# The girl collector takes care of me little by little. already exists. Skipping.
# Honey Coated S Class Guide already exists. Skipping.
# Necromancer's Evolutionary Traits already exists. Skipping.
# Sen no Sukiru o Motsu Otoko already exists. Skipping.
# Azure Legacy already exists. Skipping.
# Gomi Ika Da To Tsuihousareta Shounin, Jitsu Wa Zensei Kenja Desu already exists. Skipping.
# Finished scraping page 10
# Scraping page: https://mangapark.io/latest/action/11
# I Use The Power Of The Gods Of Daxia To Defeat The World already exists. Skipping.
# Muinnigwak already exists. Skipping.
# Honeko Akabane’s Bodyguards already exists. Skipping.
# I Awoke as a God After Auto Battling For a Million Years already exists. Skipping.
# Manadeshi ni Uragirarete Shinda Ossan Yuusha, Shijou Saikyou no Maou toshite Ikikaeru already exists. Skipping.
# 1000 Yen Hero already exists. Skipping.
# Henkyou Gurashi no Maou, Tensei shite Saikyou no Majutsushi ni naru already exists. Skipping.
# Level 1 kara Hajimaru Shoukan Musou already exists. Skipping.
# Regressor Instruction Manual already exists. Skipping.
# The Dark Magician Transmigrates After 66666 Years already exists. Skipping.
# Latna Saga: Survival of a Sword King already exists. Skipping.
# The 31st Piece Turns the Tables already exists. Skipping.
# The Game That I Came From already exists. Skipping.
# Star-Embracing Swordmaster already exists. Skipping.
# Omniscient Reader's Viewpoint already exists. Skipping.
# Davre No Oukan already exists. Skipping.
# The Zenith already exists. Skipping.
# Go! Go! Loser Ranger! already exists. Skipping.
# Solo Necromancer already exists. Skipping.
# Isekai Cheat Kaitakuki already exists. Skipping.
# Gui Shui Yi Yun already exists. Skipping.
# Return Of The Mount Hua Sect already exists. Skipping.
# Shenji Shengji Xitong already exists. Skipping.
# Leveling Up With the Gods already exists. Skipping.
# A Gifted Doctor already exists. Skipping.
# Humble System, Beg Me To Be Invincible already exists. Skipping.
# Mobile Suit Gundam Seed Freedom Astray already exists. Skipping.
# Hajime no Ippo already exists. Skipping.
# The Villain Of Destiny already exists. Skipping.
# Isekai Meikyuu De Harem O already exists. Skipping.
# ISEKAI CHEAT KAITAKUKI already exists. Skipping.
# Chamgyoyug already exists. Skipping.
# Life Of A Magic Academy Mage already exists. Skipping.
# Doomsday Sword God already exists. Skipping.
# Reincarnated As A Genius Prodigy Of A Prestigious Family already exists. Skipping.
# Ningen Kyouki Katsuo already exists. Skipping.
# Finished scraping page 11
# Scraping page: https://mangapark.io/latest/action/12
# Original Chronicle Mahou Shoujo Lyrical Nanoha The 1st already exists. Skipping.
# Valhalla Saga already exists. Skipping.
# My Disciples Are All Invincible Monsters already exists. Skipping.
# The Akashic Record Which Only I Can Read already exists. Skipping.
# Digimon Adventure V-Tamer 01 already exists. Skipping.
# Sensou Kyoushitsu already exists. Skipping.
# Isekai Meikyuu de Harem wo already exists. Skipping.
# Fairy Tail: 100 Years Quest already exists. Skipping.
# Lupin Iii: World’S Most Wanted already exists. Skipping.
# Tower Dungeon already exists. Skipping.
# Make the Exorcist Fall in Love already exists. Skipping.
# Dark Fantasy Paladin already exists. Skipping.
# The Lord of Money already exists. Skipping.
# Kabushiki Gaisha Magi Lumiere already exists. Skipping.
# Chainsaw Man already exists. Skipping.
# Return of the Blossoming Blade already exists. Skipping.
# Level 1 Player already exists. Skipping.
# Yajin Tensei Karate Survivor in Another World already exists. Skipping.
# Marriagetoxin already exists. Skipping.
# Lord Of Money already exists. Skipping.
# Modan Romanesuko already exists. Skipping.
# Eleceed already exists. Skipping.
# Cell already exists. Skipping.
# Yuusha Party wo Tsuihosareta Ore daga, Ore kara Sudattekureta you de Ureshii. ......nanode Dai Seijo, Omae ni Ottekorarete wa Komaru no daga? already exists. Skipping.
# Shin Lupin III already exists. Skipping.
# The Hero Returns already exists. Skipping.
# Infinite Mage already exists. Skipping.
# Don't Fear The Reaper already exists. Skipping.
# Entomologist In Sichuan Tang Clan already exists. Skipping.
# Vanta Black already exists. Skipping.
# My Harem Is Entirely Female Demon Villains already exists. Skipping.
# Survival Story of a Sword King in a Fantasy World already exists. Skipping.
# Reincarnation No Kaben already exists. Skipping.
# Qian Dao 30 Tian Yi Quan Bao Xing already exists. Skipping.
# Light of the Dawn already exists. Skipping.
# Tensei Kizoku no Isekai Boukenroku ~Jichou wo Shiranai Kamigami no Shito~ already exists. Skipping.
# Finished scraping page 12
# Scraping page: https://mangapark.io/latest/action/13
# Divine Urban God already exists. Skipping.
# Arcane Sniper already exists. Skipping.
# Release That Witch already exists. Skipping.
# The Book Eating Magician already exists. Skipping.
# To Hell With Being A Saint, I’m A Doctor already exists. Skipping.
# 48 Hours a Day already exists. Skipping.
# I Killed An Academy Player already exists. Skipping.
# Hallym Gymnasium already exists. Skipping.
# This Life Starts As A Child Actor already exists. Skipping.
# Gorillaman already exists. Skipping.
# Tensei Shitara Slime Datta Ken: Clayman Revenge already exists. Skipping.
# I'm Just An Immortal already exists. Skipping.
# Kill The Dragon already exists. Skipping.
# Angel Heart already exists. Skipping.
# Tate no Yuusha no Nariagari already exists. Skipping.
# Gideon of the 3rd already exists. Skipping.
# The Return Of The Crazy Demon already exists. Skipping.
# Finished scraping page 14
# Scraping page: https://mangapark.io/latest/action/15
# Shinjuku Swan already exists. Skipping.
# The Return of the Abandoned Son already exists. Skipping.
# Vain Afterimage already exists. Skipping.
# Overpowered Sword already exists. Skipping.
# Gongzi Shizai Tai Zhengyile already exists. Skipping.
# Phantom Busters already exists. Skipping.
# Shoukoku No Altair already exists. Skipping.
# Biography of Hwiyeong Sword already exists. Skipping.
# Absolute Regression already exists. Skipping.
# The Regressed Mercenary’S Machinations already exists. Skipping.
# I Reincarnated as a Legendary Surgeon already exists. Skipping.
# I Reincarnated as a Legendary Surgeon already exists. Skipping.
# The Knight King Who Returned With A God already exists. Skipping.
# Mobile Suit Gundam Pulitzer - Amuro Ray Beyond The Aurora already exists. Skipping.
# The Return of the 8th Class Magician already exists. Skipping.
# mysterious village already exists. Skipping.
# Conquer The Game With The Best Web Novels already exists. Skipping.
# Superhuman Battlefield already exists. Skipping.
# I'm a Mom already exists. Skipping.
# Revenge of the Iron-Blooded Sword Hound already exists. Skipping.
# The Hunter Wants To Live Quietly already exists. Skipping.
# I have an SSS-rank Trait, but I want a Normal Life already exists. Skipping.
# I Eat Soft Rice in Another World already exists. Skipping.
# Oh! Dangun already exists. Skipping.
# Hell Mode: Yarikomi Suki no Gamer wa Hai Settei no Isekai de Musou Suru already exists. Skipping.
# I Am Behemoth of the S-Rank Monster, But I Am Mistaken as a Cat and I Live as a Pet of Elf Girl already exists. Skipping.
# Myst, Might, Mayhem already exists. Skipping.
# Keep A Low Profile, Sect Leader already exists. Skipping.
# Subscribed To The Transcendental Channels already exists. Skipping.
# The Genius Tamer Of The Academy already exists. Skipping.
# Seoul Station Barbarian already exists. Skipping.
# The Academy's Genius Tamer already exists. Skipping.
# This Account Is Ridiculous already exists. Skipping.
# Garan no Hime already exists. Skipping.
# Tensei Shitara Slime Datta Ken already exists. Skipping.
# Brilliant Galaxy already exists. Skipping.
# Finished scraping page 15
# Scraping page: https://mangapark.io/latest/action/16
# Metalial Story already exists. Skipping.
# The Priest of Corruption already exists. Skipping.
# Gods of all people: I sacrificed hundreds of millions of living beings to become a god already exists. Skipping.
# Tower of God already exists. Skipping.
# Netachara Tensei Toka Anmarida! already exists. Skipping.
# The Novel’s Extra (2022) already exists. Skipping.
# Second-Life Cheat Mage: Life Turned Out to Be Easy after Being Reincarnated 1,000 Years into the Future already exists. Skipping.
# The Heavenly Demon Can't Live A Normal Life already exists. Skipping.
# The Rogue Prince Is Secretly An Omega already exists. Skipping.
# Youngest Son Of The Renowned Magic Clan already exists. Skipping.
# Invincible Martial Sage already exists. Skipping.
# Moscow 2160 already exists. Skipping.
# That Time I Got Reincarnated as a Slime already exists. Skipping.
# Shaman King: The Super Star already exists. Skipping.
# Finished scraping page 20
# Scraping page: https://mangapark.io/latest/action/21
# It All Starts With Playing Game Seriously already exists. Skipping.
# Magical Girl Raising Project already exists. Skipping.
# Higanjima - Saigo No 47 Hiai already exists. Skipping.
# Evolution Begins With A Big Tree already exists. Skipping.
# Higanjima: Saigo no 47 Nichikan already exists. Skipping.
# I’m From Alien Space already exists. Skipping.
# Book Of The Dead already exists. Skipping.
# Onmir The oddity already exists. Skipping.
# Saint Seiya - Rerise of Poseidon already exists. Skipping.
# Tianqi Yubao already exists. Skipping.
# All the Female Apprentices Want to Kill Me already exists. Skipping.
# Bones already exists. Skipping.
# The King Of Snow already exists. Skipping.
# Kaijuu Jieitai: Task Force for Paranormal Disaster Management already exists. Skipping.
# Zombie X Slasher already exists. Skipping.
# Transmigrating to the Otherworld Once More already exists. Skipping.
# Back From Black already exists. Skipping.
# Unstoppable Hayeong already exists. Skipping.
# Temple Of Dragon King already exists. Skipping.
# I Became The King by Scavenging already exists. Skipping.
# null already exists. Skipping.
# Kimi no Koto ga Daidaidaidaidaisuki na 100-nin no Kanojo already exists. Skipping.
# This World is Money and Power already exists. Skipping.
# Youngest son of the renowned swordsmanship clan already exists. Skipping.
# Tales Of Sarimin The Jinn already exists. Skipping.
# Toshiue Elite Onna Kishi ga Boku no Mae de dake Kawaii already exists. Skipping.
# Return to Player already exists. Skipping.
# Dao of the Bizarre Immortal already exists. Skipping.
# Mercenary Enrollment already exists. Skipping.
# A Bad Person already exists. Skipping.
# Grand Dwarf already exists. Skipping.
# The Eminence in Shadow: Shadow Side Story. already exists. Skipping.
# The Mysterious World's Greatest Martial Artist Little Prince already exists. Skipping.
# Losing Money To Be A Tycoon already exists. Skipping.
# Earth With Dungeon: Koyuu Skill “Touka Koukan Store” O Kushi Shite Sekai Kyuusai O Mezashimasu already exists. Skipping.
# Hunter x Hunter already exists. Skipping.
# Finished scraping page 21
# Scraping page: https://mangapark.io/latest/action/22
# The Suspicious Boy Is One of the World's Top Ten Masters already exists. Skipping.
# The Steward Demonic Emperor already exists. Skipping.
# Catastrophic Necromancer already exists. Skipping.
# Seoul Station Druid already exists. Skipping.
# I Really Don't Want to Learn Forbidden Spells already exists. Skipping.
# I Became The King by Scavenging already exists. Skipping.
# Japan Summons already exists. Skipping.
# Cyfandir Chronicles already exists. Skipping.
# Ranker's Return (Remake) already exists. Skipping.
# Ranker's Return (2021) already exists. Skipping.
# Transcension Academy already exists. Skipping.
# Heir Of Mythical Heroes already exists. Skipping.
# The Ravages of Time already exists. Skipping.
# The Holy Knight's Dark Road already exists. Skipping.
# Strongest Level 1 already exists. Skipping.
# Regressor Instruction Manual already exists. Skipping.
# Wonderful Precure! already exists. Skipping.
# Feng ni Tianxia already exists. Skipping.
# A Legend of Ultimate Hot Rodder already exists. Skipping.
# My Ruined Academy already exists. Skipping.
# Legendary Blacksmith's Vengeance already exists. Skipping.
# Gundam Exa Vs already exists. Skipping.
# Rust already exists. Skipping.
# (IDW) Sonic the Hedgehog already exists. Skipping.
# The Evil God Descends, I Own Great Hell already exists. Skipping.
# The Son Of The First Emperor Kills Enemies And Becomes A God already exists. Skipping.
# Quan Zhiye Yongzhe already exists. Skipping.
# Muscle Archmage already exists. Skipping.
# Emperor Qin returns! I am the Eternal Immortal Emperor already exists. Skipping.
# Left Handed Mutation already exists. Skipping.
# Gamer ga Isekai Tamashiten shite Harem Jinsei e Continue suru Sou desu already exists. Skipping.
# Fate/Grand Order: Qin Shi Huang's Interlude - The Melancholy of a Ruler already exists. Skipping.
# My Job is Appraiser, but What is The [God Eye]? Living Freely with The World's Greatest Elementary Level Job already exists. Skipping.
# DHM - Dungeon + Harem + Master already exists. Skipping.
# After 10000 years I will do whatever I want already exists. Skipping.
# Isekai De Cheat Skill Wo Te Ni Shita Ore Wa, Genjitsu Sekai Wo Mo Musou Suru: Girls Side ~Kareinaru Otome-Tachi No Bouken Wa Sekai Wo Kaeta~ already exists. Skipping.
# Journey to the West (Zheng Jian He) already exists. Skipping.
# Gacha wo Mawashite Nakama wo Fuyasu Saikyou no Bishoujo Gundan wo Tsukuriagero already exists. Skipping.
# Shijou Saikyou no Mahou Kenshi, F-Rank Boukensha ni Tensei suru: Kensei to Matei, Futatsu no Zense wo Motta Otoko no Eiyuutan already exists. Skipping.
# Akuyaku Onzoushi no Kanchigai Seija Seikatsu - Nidome no Jinsei wa Yaritai Houdai Shitai Dake na no ni already exists. Skipping.
# Isekai Mahou wa Okureteru! already exists. Skipping.
# A classmate is a princess knight! already exists. Skipping.
# Soul Land already exists. Skipping.
# Doom Lord (Novel) already exists. Skipping.
# Kono Healer, Mendokusai already exists. Skipping.
# The World's Fastest Level Up! already exists. Skipping.
# Qi Refining Level 3000: Accept the Empress as your disciple already exists. Skipping.
# Jinmen already exists. Skipping.
# Finished scraping page 52
# Scraping page: https://mangapark.io/latest/action/53
# Outrageous! I Opened a Training Class for Empresses already exists. Skipping.
# Tale of a Scribe Who Retires to the Countryside already exists. Skipping.
# Samurai in Another World already exists. Skipping.
# The Immortal Me X Destroyer Girl already exists. Skipping.
# Fate/Grand Order -Epic of Remnant- Deep Sea Cyber-Paradise SE.RA.PH already exists. Skipping.
# Ninkyou Tensei already exists. Skipping.
# Star of the Overlord already exists. Skipping.
# Drop OG - Out of Ganchu already exists. Skipping.
# Rebirth of King Zhou: Not Being the Ultimate Villain already exists. Skipping.
# The Lazy Lord Masters the Sword already exists. Skipping.
# Neon Revenge already exists. Skipping.
# The Invincible Me Just Wants to Be Ordinary already exists. Skipping.
# Is It Odd That I Become An Adventurer Even If I Graduated The Witchcraft Institute? already exists. Skipping.
# Murim Login already exists. Skipping.
# Dragon Tofu already exists. Skipping.
# Dragon Emperor, Martial God (Novel) already exists. Skipping.
# The Strong, The Few, True Cultivators on Campus (Novel) already exists. Skipping.
# Re: Monarch already exists. Skipping.
# Meccha Shoukan Sareta Ken (Tsugutoku) already exists. Skipping.
# Way To Heaven (Chonbu) already exists. Skipping.
# Is It Odd That I Became An Adventurer Even If I Graduated The Witchcraft Institute? already exists. Skipping.
# The Legendary Hunter Becomes Young Again already exists. Skipping.
# 99 Boss already exists. Skipping.
# Realist Maou Niyoru Seiiki Naki Isekai Kaikaku already exists. Skipping.
# Forging an Industrial Empire in a Magical World already exists. Skipping.
# Yajin Tensei: Karate Survivor in Another World already exists. Skipping.
# The Ten Thousand Clans Invasion: Guardian of the Rear already exists. Skipping.
# The Legend of Rebuilding World Realist Demon King already exists. Skipping.
# Jinsei Ni Tsukareta Saikyou Majutsushi Wa Akiramete Nemuru Koto Ni Shita already exists. Skipping.
# D.Gray-man already exists. Skipping.
# Dragon Quest: Dai no Daibouken - Yuusha Avan to Gokuen no Maou already exists. Skipping.
# Hoankan Evans no Uso already exists. Skipping.
# The Supreme Almighty Master Remake already exists. Skipping.
# My Sister’s Private Life already exists. Skipping.
# Kage no Jitsuryokusha ni Naritakute already exists. Skipping.
# I'm a Curse Crafter, and I Don't Need an S-Rank Party! already exists. Skipping.
# Finished scraping page 53
# Scraping page: https://mangapark.io/latest/action/54
# Dragon Quest: Dai no Daibouken - Yuusha Avan to Gokuen no Maou already exists. Skipping.
# Isekai Kenja no Tensei Musou ~Geemu no Chishiki de Isekai Saikyou~ already exists. Skipping.
# The Ten Thousand Clans Invasion: Guardian of the Rear already exists. Skipping.
# Stairs (Ongoo) already exists. Skipping.
# Bungo Stray Dogs already exists. Skipping.
# Muhyo to Roji no Mahouritsu Soudan Jimusho: Mazoku Magushi-hen already exists. Skipping.
# Hagun Seisenki already exists. Skipping.
# Tora Wa Ryuu Wo Mada Tabenai. already exists. Skipping.
# Scarlet Star already exists. Skipping.
# Gokurakugai already exists. Skipping.
# Survive As The Hero’s Husband! already exists. Skipping.
# Mountain And Sea Continent already exists. Skipping.
# The Eminence in Shadow already exists. Skipping.
# The Eminence in Shadow already exists. Skipping.
# Alive already exists. Skipping.
# Heavenly Blood Star already exists. Skipping.
# Escape Game (Hong Yao & VON) already exists. Skipping.
# I’m A Martial Art Villainess But I’m The Strongest! already exists. Skipping.
# Day Walker already exists. Skipping.
# My Wife is a Heavenly Big Shot already exists. Skipping.
# Yuusha Party Okubi Ni Natta Ninja, Shinobazu Ni Ikimasu already exists. Skipping.
# Higanjima - Saigo no 47 Hiai already exists. Skipping.
# The Solo Munching Game Breaker already exists. Skipping.
# The Spellbook Library already exists. Skipping.
# OnePunch-Man (ONE) already exists. Skipping.
# A Girl Who Longed To Be A already exists. Skipping.
# Instantaneous Space already exists. Skipping.
# Class ga Isekai Shoukan sareta Naka Ore dake Nokotta n desu ga already exists. Skipping.
# Yakuza Reincarnation already exists. Skipping.
# Class ga Isekai Shoukan sareta Naka Ore dake Nokotta n desu ga already exists. Skipping.
# Fate/Grand Order: Turas Réalta already exists. Skipping.
# Ryuu to Ayumu Nariagari Boukensha-dou ~ Youzumi toshite S-Rank Party kara Tsuihou Sareta Kaifuku Majutsushi, Suterareta Saki de Saikyou no Shinryuu wo Fukkatsu Sasete Shimau ~ already exists. Skipping.
# Mobile Suit Gundam Narrative already exists. Skipping.
# Eternal God Emperor (Novel) already exists. Skipping.
# Heaven Official's Blessing (Novel) already exists. Skipping.
# The Tutorial Tower of the Advanced Player already exists. Skipping.
# Finished scraping page 54
# Scraping page: https://mangapark.io/latest/action/55
# Fate/grand Order -Turas Réalta- already exists. Skipping.
# Taiyou to Tsuki no Hagane already exists. Skipping.
# Code Name: TARANTULA already exists. Skipping.
# My Otherworldly Sisters Won't Hold Back! already exists. Skipping.
# Nirvana (Jin) already exists. Skipping.
# Fate/Grand Order -mortalis:stella- already exists. Skipping.
# Fate/Grand Order: Mortalis:Stella already exists. Skipping.
# Zero 0 – Transcending the future with space-time magic already exists. Skipping.
# The guild official with weak skill "VANISH" is actually legendary assassin already exists. Skipping.
# Tianji Shen Shu Shi: Wangye Xianggong Buxin Xie already exists. Skipping.
# The Immortal's Path already exists. Skipping.
# The Strongest God of War in the City already exists. Skipping.
# Wo Zai Difu Kai Hougong already exists. Skipping.
# Mobile Suit Gundam - The Revival of Zeon already exists. Skipping.
# World Defying Dan God (Novel) already exists. Skipping.
# Level 596 no Tanya Minarai already exists. Skipping.
# Yuusha Party Wo Tsuihou Sareta "skill Supporter," Nakama No Sukiru Wo Kaihou Shite Saikyou Ni Nariagaru already exists. Skipping.
# Kiwamete Goumantaru Akuyaku Kizoku No Shogyou already exists. Skipping.
# Fate/grand Order: Epic Of Remnant - Subspecies Singularity Iv: Taboo Advent Salem: Salem Of Heresy already exists. Skipping.
# Hazure Skill "Kage ga Usui" o Motsu Guild Shokuin ga, Jitsu wa Densetsu no Ansatsusha already exists. Skipping.
# Isekai Teni Shita node Cheat o Ika Shite Mahou Kenshi Yaru Koto ni Suru already exists. Skipping.
# Crazy Leveling System already exists. Skipping.
# Mobile Suit Gundam Seed Eclipse already exists. Skipping.
# Hazure Skill: The Guild Member with a Worthless Skill Is Actually a Legendary Assassin already exists. Skipping.
# Estio (Ppungppa) already exists. Skipping.
# Mach Go Go Go already exists. Skipping.
# Isekai Kokka Alchimaira: Saijaku no Ou to Musou no Gunzei already exists. Skipping.
# Sekai Saikyou no Kouei: Meikyuukoku no Shinjin Tansakusha (Novel) already exists. Skipping.
# Nanbaka already exists. Skipping.
# Neun already exists. Skipping.
# Kuni Wo Owareta Ryuushi-San, Hirowareta Ringoku De Ukkari Musou Shite Shimau. already exists. Skipping.
# Get the Heroine's Script already exists. Skipping.
# Return Of The Genius Player already exists. Skipping.
# Fate/grand Order: Epic Of Remnant - Pseudo-Singularity I: Quarantined Territory Of Malice, Shinjuku - Shinjuku Phantom Incident already exists. Skipping.
# Motto Mo Kirawareteiru Saikyou No Akuyaku Ni Tensei already exists. Skipping.
# Unholy Blood already exists. Skipping.
# Finished scraping page 55
# Data saved to manga_data.json

# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import os

def scrape_and_update_anime_data(base_url, output_file):
    if os.path.exists(output_file):
        with open(output_file, 'r', encoding='utf-8') as file:
            existing_data = json.load(file)
    else:
        existing_data = []

    existing_titles = {anime['title'] for anime in existing_data}

    new_anime_data = []
    page_num = 1
    while True:
        page_url = base_url + str(page_num)
        response = requests.get(page_url)

        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')
            anime_list = soup.find_all('article', class_='bs')

            if not anime_list:
                print(f"No anime found on page {page_num}. Stopping.")
                break

            for anime in anime_list:
                title = anime.find('a')['title']

                if title in existing_titles:
                    continue

                episode_link = anime.find('a')['href']
                image_url = anime.find('img')['src']

                try:
                    episode_response = requests.get(episode_link)
                    if episode_response.status_code == 200:
                        episode_soup = BeautifulSoup(episode_response.content, 'html.parser')
                        iframe_element = episode_soup.find('iframe')
                        if iframe_element:
                            video_url = iframe_element.get('src')
                        else:
                            video_url = "No video URL found"
                    else:
                        video_url = "Failed to retrieve video URL"
                except Exception as e:
                    video_url = f"Error occurred: {str(e)}"

                new_anime_data.append({
                    'title': title,
                    'episode_link': episode_link,
                    'image_url': image_url,
                    'video_url': video_url
                })

                time.sleep(1)

            print(f"Successfully scraped page {page_num}")
        else:
            print(f"Failed to retrieve page {page_num}. Status code: {response.status_code}")
            break

        page_num += 1

    combined_data = existing_data + new_anime_data

    with open(output_file, 'w', encoding='utf-8') as json_file:
        json.dump(combined_data, json_file, ensure_ascii=False, indent=4)

    print(f"Data successfully written to {output_file}")
    print(f"New entries added: {len(new_anime_data)}")


base_url = 'https://chia-anime.su/page/'
output_file = 'all_anime_data.json'

scrape_and_update_anime_data(base_url, output_file)
# Out:
# Successfully scraped page 1
# Successfully scraped page 2
# Successfully scraped page 3
# Successfully scraped page 4
# Successfully scraped page 5
# Successfully scraped page 6
# Successfully scraped page 7
# Successfully scraped page 8
# Successfully scraped page 9
# Successfully scraped page 10
# Successfully scraped page 11
# Successfully scraped page 12
# Successfully scraped page 13
# Successfully scraped page 14
# Successfully scraped page 15
# Successfully scraped page 16
# Successfully scraped page 17
# Successfully scraped page 18
# Successfully scraped page 19
# Successfully scraped page 20
# Successfully scraped page 21
# Successfully scraped page 22
# Successfully scraped page 23
# Successfully scraped page 24
# Successfully scraped page 25
# Successfully scraped page 26
# Successfully scraped page 27
# Successfully scraped page 28
# Failed to retrieve page 29. Status code: 404
# Data successfully written to all_anime_data.json
# New entries added: 0

# %%
import os
import json
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import time

options = webdriver.ChromeOptions()
options.add_argument('--headless')
options.add_argument('--no-sandbox')
options.add_argument('--disable-dev-shm-usage')
driver = webdriver.Chrome(options=options)

def update_chapters_and_images_immediate(manga_file="manga_data.json"):
    if not os.path.exists(manga_file):
        print(f"File {manga_file} does not exist. Please scrape manga data first.")
        return

    with open(manga_file, "r") as file:
        manga_data = json.load(file)

    for title, details in manga_data.items():
        print(f"Checking updates for {title}...")

        response = requests.get(details["details_url"])
        if response.status_code != 200:
            print(f"Failed to fetch details for {title}. Skipping.")
            continue

        soup = BeautifulSoup(response.content, "html.parser")
        chapter_elements = soup.select("a.link-hover.link-primary.visited\\:text-accent")
        chapters_on_site = [
            {"title": chapter.text.strip(), "url": "https://mangapark.io" + chapter["href"]}
            for chapter in chapter_elements
        ]

        existing_chapters = {ch["title"] for ch in details.get("chapters", [])}
        new_chapters = [ch for ch in chapters_on_site if ch["title"] not in existing_chapters]

        if new_chapters:
            print(f"Adding {len(new_chapters)} new chapters for {title}.")
            details["chapters"] = details.get("chapters", []) + new_chapters

        for chapter in details["chapters"]:
            if "images" not in chapter or not chapter["images"]:
                print(f"Scraping images for {chapter['title']}...")
                try:
                    driver.get(chapter["url"])
                    time.sleep(5)
                    chapter_soup = BeautifulSoup(driver.page_source, "html.parser")
                    image_elements = chapter_soup.select("div[data-name='image-show'] img")
                    chapter["images"] = [img["src"] for img in image_elements]
                    print(f"Updated images for {chapter['title']}: {len(chapter['images'])} images found.")
                except Exception as e:
                    print(f"An error occurred while scraping images for {chapter['title']}: {e}")

            manga_data[title] = details
            with open(manga_file, "w") as file:
                json.dump(manga_data, file, indent=4)
            print(f"Chapter {chapter['title']} updated successfully.")

    print("All manga data updated.")

update_chapters_and_images_immediate()
driver.quit()

# %%
import schedule
import time
from datetime import datetime, timedelta
from pytz import timezone
from concurrent.futures import ThreadPoolExecutor, wait, ALL_COMPLETED

def run_scrape_anime():
    base_url = 'https://chia-anime.su/page/'
    output_file = 'all_anime_data.json'
    scrape_and_update_anime_data(base_url, output_file)

def run_scrape_manga():
    scrape_manga()

def run_update_chapters_and_images():
    update_chapters_and_images_immediate()

def run_all_tasks():
    with ThreadPoolExecutor() as executor:
        anime_future = executor.submit(run_scrape_anime)
        manga_future = executor.submit(run_scrape_manga)
        wait([anime_future, manga_future], return_when=ALL_COMPLETED)
        print("Both scraping tasks completed. Running update_chapters_and_images_immediate...")
        run_update_chapters_and_images()
        print("Update process completed.")

def time_until_12_am_ist():
    ist = timezone('Asia/Kolkata')
    now = datetime.now(ist)
    next_midnight = (now + timedelta(days=1)).replace(hour=0, minute=0, second=0, microsecond=0)
    if now.hour == 0 and now.minute == 0 and now.second == 0:
        return None
    return next_midnight - now

if __name__ == "__main__":
    time_left = time_until_12_am_ist()

    if time_left:
        print(
            f"Time left until 12 AM IST: "
            f"{time_left.seconds // 3600} hours, "
            f"{(time_left.seconds % 3600) // 60} minutes, "
            f"{time_left.seconds % 60} seconds, "
            f"{time_left.microseconds // 1000} milliseconds."
        )
    else:
        print("It's 12 AM IST. Running the process...")
        schedule.every().day.at("00:00").do(run_all_tasks)

        while True:
            schedule.run_pending()
            time.sleep(1)
# Out:
# Time left until 12 AM IST: 0 hours, 47 minutes, 39 seconds, 245 milliseconds.

# %%
# !pip install schedule
# Out:
# Collecting schedule
#   Downloading schedule-1.2.2-py3-none-any.whl.metadata (3.8 kB)
# Downloading schedule-1.2.2-py3-none-any.whl (12 kB)
# Installing collected packages: schedule
# Successfully installed schedule-1.2.2

# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Downloading selenium-4.27.1-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: urllib3<3,>=1.26 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (2.2.3)
# Collecting trio~=0.17 (from selenium)
#   Downloading trio-0.27.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting trio-websocket~=0.9 (from selenium)
#   Downloading trio_websocket-0.11.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: certifi>=2021.10.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (2024.8.30)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.10/dist-packages (from selenium) (4.12.2)
# Requirement already satisfied: websocket-client~=1.8 in /usr/local/lib/python3.10/dist-packages (from selenium) (1.8.0)
# Requirement already satisfied: attrs>=23.2.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (24.2.0)
# Collecting sortedcontainers (from trio~=0.17->selenium)
#   Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (3.10)
# Collecting outcome (from trio~=0.17->selenium)
#   Downloading outcome-1.3.0.post0-py2.py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.3.1)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from trio~=0.17->selenium) (1.2.2)
# Collecting wsproto>=0.14 (from trio-websocket~=0.9->selenium)
#   Downloading wsproto-1.2.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Downloading selenium-4.27.1-py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 74.5 MB/s eta 0:00:00
# Downloading trio-0.27.0-py3-none-any.whl (481 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.7/481.7 kB 33.2 MB/s eta 0:00:00
# Downloading trio_websocket-0.11.1-py3-none-any.whl (17 kB)
# Downloading wsproto-1.2.0-py3-none-any.whl (24 kB)
# Downloading outcome-1.3.0.post0-py2.py3-none-any.whl (10 kB)
# Downloading sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Installing collected packages: sortedcontainers, wsproto, outcome, trio, trio-websocket, selenium
# Successfully installed outcome-1.3.0.post0 selenium-4.27.1 sortedcontainers-2.4.0 trio-0.27.0 trio-websocket-0.11.1 wsproto-1.2.0
